# %%
#COMPUTER VISION-> 1.CLASSIFICATION   2.OBJECT DETECTION  3.Segmentation

# %%
#step1 : Pretained model  #step2: Custom model(#transfer learning)

# %%
#1 classification
# !pip install ultralytics

# %%
#1 classification

from ultralytics import YOLO
CLASSIFIER_ENGINE=YOLO("yolov8n-cls.pt");
RESULT= CLASSIFIER_ENGINE.predict(source='TEST/zebra.jpg',save=True,save_txt=True)
# Out:
# image 1/1 C:\Users\vihan\TEST\zebra.jpg: 224x224 zebra 1.00, tiger 0.00, triceratops 0.00, tiger_cat 0.00, park_bench 0.00, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs\classify\predict
# 1 label saved to runs\classify\predict\labels

# %%
#2 object detection

from ultralytics import YOLO
DETECTION_ENGINE=YOLO("yolov8n.pt")
RESULT=DETECTION_ENGINE.predict(source='TEST/OIP.jpeg',save=True, save_txt=True)
# Out:
# image 1/1 C:\Users\vihan\TEST\OIP.jpeg: 640x480 1 person, 275.0ms
# Speed: 7.2ms preprocess, 275.0ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels

# %%
#3 Segmentation
from ultralytics import yolo
segmentation_engine=YOLO("yolov8n-seg.pt")
result=segmentation_engine.predict(source='TEST', save=True, save_txt=True)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# image 1/3 C:\Users\vihan\TEST\OIP.jpeg: 640x480 1 person, 316.1ms
# image 2/3 C:\Users\vihan\TEST\zebra.jpg: 448x640 1 zebra, 304.2ms
# video 3/3 (1/305) C:\Users\vihan\TEST\HD.mkv: 384x640 4 persons, 3 cars, 229.1ms
# video 3/3 (2/305) C:\Users\vihan\TEST\HD.mkv: 384x640 3 persons, 3 cars, 204.0ms
# video 3/3 (3/305) C:\Users\vihan\TEST\HD.mkv: 384x640 2 persons, 3 cars, 221.6ms
# ...

# %%
from ultralytics import YOLO
seg=YOLO("yolov8n-seg.pt")
result=seg.predict(source="TEST/HD.mkv", save=True, stream=True, save_txt=True)

# %%
from ultralytics import YOLO
seg=YOLO("yolov8n-seg.pt")
result=seg.predict(source="TEST/HD.mkv", save=True,save_txt=True)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/305) C:\Users\vihan\TEST\HD.mkv: 384x640 4 persons, 3 cars, 286.3ms
# video 1/1 (2/305) C:\Users\vihan\TEST\HD.mkv: 384x640 3 persons, 3 cars, 297.5ms
# video 1/1 (3/305) C:\Users\vihan\TEST\HD.mkv: 384x640 2 persons, 3 cars, 234.0ms
# video 1/1 (4/305) C:\Users\vihan\TEST\HD.mkv: 384x640 3 persons, 3 cars, 167.7ms
# video 1/1 (5/305) C:\Users\vihan\TEST\HD.mkv: 384x640 2 persons, 3 cars, 243.6ms
# ...

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.0.105
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://github.com/ultralytics/ultralytics
# Author: Ultralytics
# Author-email: hello@ultralytics.com
# License: AGPL-3.0
# Location: c:\users\vihan\anaconda3\lib\site-packages
# Requires: matplotlib, opencv-python, pandas, Pillow, psutil, PyYAML, requests, scipy, seaborn, sentry-sdk, torch, torchvision, tqdm
# Required-by:

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cpu'

# %%
#training of model

from ultralytics import YOLO

## model=YOLO()   # use this if you want to train your model

model=YOLO('yolov8n.pt')    # load a pretrained yolov8n model

# %%
import os
Result= model.train(data='data.yaml',epochs=3)#train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.29 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.105  Python-3.10.9 torch-2.0.1+cpu CPU
# ...
